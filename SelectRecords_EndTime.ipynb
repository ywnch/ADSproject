# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('JoinedEvent_CB2016_subset_1km.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
#
#         start station name  start station latitude  start station longitude  \
# 0  Fulton St & Rockwell Pl               40.688226               -73.979382
#
#    end station id             end station name    ...     \
# 0             241  DeKalb Ave & S Portland Ave    ...
#
#    end station longitude  bikeid    usertype birth year  gender   startdate  \
# 0             -73.974931   23976  Subscriber     1971.0       2  2016-01-01
#
#      stopdate Event_type             End_Time    E_Time
# 0  2016-01-01        NaN  2017-12-05 21:00:00  21:00:00
#
# [1 rows x 21 columns]

# %%
df.keys()
# Out:
# Index([u'Unnamed: 0', u'tripduration', u'starttime', u'stoptime',
#        u'start station id', u'start station name', u'start station latitude',
#        u'start station longitude', u'end station id', u'end station name',
#        u'end station latitude', u'end station longitude', u'bikeid',
#        u'usertype', u'birth year', u'gender', u'startdate', u'stopdate',
#        u'Event_type', u'End_Time', u'E_Time'],
#       dtype='object')

# %%
len(df)
# Out:
# 100666

# %%
df['TripStartHM'] = pd.to_datetime(df['starttime']).dt.hour + pd.to_datetime(df['starttime']).dt.minute / 60

# %%
df['EventEndHM'] = pd.to_datetime(df['End_Time']).dt.hour + pd.to_datetime(df['End_Time']).dt.minute / 60

# %%
df.head(1)
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
#
#         start station name  start station latitude  start station longitude  \
# 0  Fulton St & Rockwell Pl               40.688226               -73.979382
#
#    end station id             end station name    ...        usertype  \
# 0             241  DeKalb Ave & S Portland Ave    ...      Subscriber
#
#    birth year  gender   startdate    stopdate  Event_type  \
# 0      1971.0       2  2016-01-01  2016-01-01         NaN
#
#               End_Time    E_Time TripStartHM EventEndHM
# 0  2017-12-05 21:00:00  21:00:00       16.05       21.0
#
# [1 rows x 23 columns]

# %%
filtered = df[(df['TripStartHM'] > df['EventEndHM']) & (df['TripStartHM'] < df['EventEndHM']+1)]

# %%
len(filtered)
# Out:
# 9669

# %%
filtered.reset_index(inplace=True)
filtered.drop(['Unnamed: 0','index'],axis=1,inplace=True)
#filtered.drop('',axis=1,inplace=True)
filtered.head()
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    tripduration starttime  stoptime  start station id  \
# 0           609  21:09:36  21:19:46               395
# 1           397  21:51:17  21:57:54                83
# 2           218  21:06:04  21:09:42               416
# 3           638  21:06:16  21:16:54               416
# 4           278  21:07:57  21:12:36               395
#
#               start station name  start station latitude  \
# 0      Bond St & Schermerhorn St               40.688070
# 1  Atlantic Ave & Fort Greene Pl               40.683826
# 2  Cumberland St & Lafayette Ave               40.687534
# 3  Cumberland St & Lafayette Ave               40.687534
# 4      Bond St & Schermerhorn St               40.688070
#
#    start station longitude  end station id                end station name  \
# 0               -73.984106             406          Hicks St & Montague St
# 1               -73.976323             365           Fulton St & Grand Ave
# 2               -73.972652             399     Lafayette Ave & St James Pl
# 3               -73.972652            3222         Hanson Pl & St Felix St
# 4               -73.984106             274  Lafayette Ave & Fort Greene Pl
#
#    end station latitude    ...        usertype  birth year gender   startdate  \
# 0             40.695128    ...      Subscriber      1962.0      1  2016-01-01
# 1             40.682232    ...      Subscriber      1970.0      1  2016-01-01
# 2             40.688515    ...      Subscriber      1986.0      1  2016-01-02
# 3             40.685160    ...      Subscriber      1974.0      1  2016-01-02
# 4             40.686919    ...      Subscriber      1984.0      1  2016-01-02
#
#      stopdate  Event_type             End_Time    E_Time TripStartHM  \
# 0  2016-01-01         NaN  2017-12-05 21:00:00  21:00:00   21.150000
# 1  2016-01-01         NaN  2017-12-05 21:00:00  21:00:00   21.850000
# 2  2016-01-02  basketball  2016-01-02 21:00:00  21:00:00   21.100000
# 3  2016-01-02  basketball  2016-01-02 21:00:00  21:00:00   21.100000
# 4  2016-01-02  basketball  2016-01-02 21:00:00  21:00:00   21.116667
#
#   EventEndHM
# 0       21.0
# 1       21.0
# 2       21.0
# 3       21.0
# 4       21.0
#
# [5 rows x 22 columns]

# %%
filtered.to_csv('SelectRecords_EndTime_subset_1km.csv')
