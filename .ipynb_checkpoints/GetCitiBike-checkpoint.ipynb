# %% [markdown]
# # Data Management: Citi Bike 2016 Dataset
#
# ## This notebook:
# 1. Downloads Citi Bike Data in 2016
# 2. Subsets stations within a range of Barclays Center using Carto DB SQL query
# 3. Subsets trips made within a time range
# 4. Returns a list of stations in 2016 (stations_2016.csv)
# 5. Returns a csv with subset Citi Bike trips ('CB2016\_subset\_%sm_%h.csv'%(dist, time))

# %% [markdown]
# ## Set parameters

# %%
# set Euclidean distance as radius from Barclays Center
dist = 800

# set the hour of day before which the trips will be dropped
# i.e. subset trips within x to 24 hour of day only
time = 16

# %% [markdown]
# ## Download Data

# %%
# import packages
import os
import sys
import numpy as np
import pandas as pd

# %%
# import the getCitiBikeCSV function from Prof. Bianco (fedhere)
def getCitiBikeCSV(datestring):
    '''Downloads citibike data and unzips it.
       If the data is downloaded by not unzippeds it zips it.
       Moves the data to $PUIDATA
    Arguments:
        date string as yyyymm
    '''
    print ("Downloading", datestring)
    ### First I will heck that it is not already there
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        if os.path.isfile(datestring + "-citibike-tripdata.csv"):
            # if in the current dir just move it
            if os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA")):
                print ("Error moving file!, Please check!")
        #otherwise start looking for the zip file
        else:
            if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip"):
                if not os.path.isfile(datestring + "-citibike-tripdata.zip"):
                    os.system("curl -O https://s3.amazonaws.com/tripdata/" + datestring + "-citibike-tripdata.zip")
                ###  To move it I use the os.system() functions to run bash commands with arguments
                os.system("mv " + datestring + "-citibike-tripdata.zip " + os.getenv("PUIDATA"))
            ### unzip the csv 
            os.system("unzip " + os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip")
            ## NOTE: old csv citibike data had a different name structure. 
            if '2014' in datestring:
                os.system("mv " + datestring[:4] + '-' +  datestring[4:] + 
                          "\ -\ Citi\ Bike\ trip\ data.csv " + datestring + "-citibike-tripdata.csv")
            os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA"))
    ### One final check:
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        print ("WARNING!!! something is wrong: the file is not there!")

    else:
        print ("file in place, you can continue")

# %%
# download Citi Bike data in 2016
for i in range(12):
    datestring = str(201601 + i)
    getCitiBikeCSV(datestring)
# Out:
# Downloading 201601
# file in place, you can continue
# Downloading 201602
# file in place, you can continue
# Downloading 201603
# file in place, you can continue
# Downloading 201604
# file in place, you can continue
# Downloading 201605
# file in place, you can continue
# Downloading 201606
# file in place, you can continue
# Downloading 201607
# file in place, you can continue
# Downloading 201608
# file in place, you can continue
# Downloading 201609
# file in place, you can continue
# Downloading 201610
# file in place, you can continue
# Downloading 201611
# file in place, you can continue
# Downloading 201612
# file in place, you can continue

# %% [markdown]
# ## Generate station data

# %%
# use latest data (2016/12) to obtain unique stations
CB = pd.read_csv(os.getenv("PUIDATA") + "/" + '201609' + "-citibike-tripdata.csv")
CB.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# extract data from non-duplicated start stations
stations = CB.drop_duplicates('start station id')
stations.sort_values('start station id', inplace=True)
stations = stations.iloc[:,range(3,7)]
stations['Coordinates'] = list(zip(stations['start station latitude'], stations['start station longitude']))
stations.head()
# Out:
# /Users/Yuwen/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       start station id             start station name  start station latitude  \
# 255                 72               W 52 St & 11 Ave               40.767272
# 2152                79       Franklin St & W Broadway               40.719116
# 383                 82         St James Pl & Pearl St               40.711174
# 356                 83  Atlantic Ave & Fort Greene Pl               40.683826
# 18                 116                W 17 St & 8 Ave               40.741776
#
#       start station longitude                  Coordinates
# 255                -73.993929  (40.76727216, -73.99392888)
# 2152               -74.006667  (40.71911552, -74.00666661)
# 383                -74.000165  (40.71117416, -74.00016545)
# 356                -73.976323  (40.68382604, -73.97632328)
# 18                 -74.001497  (40.74177603, -74.00149746)

# %%
# export csv to Carto for query analysis
stations.to_csv('stations_2016.csv')

# %% [markdown]
# ## Identify stations within 800 meter of the Barclays Center

# %%
# import packages (compatible between py2 and py3)
try:
    import urllib2
    from urllib2 import HTTPError
    from urllib2 import urlopen
    from urllib import urlencode
    from StringIO import StringIO as io

except ImportError:
    import urllib
    from urllib.error import HTTPError
    from urllib.request import urlopen, Request
    from urllib.parse import urlencode
    from io import BytesIO as io

import ast

# %%
# set SQL source
SQL_SOURCE = 'https://ywc249.carto.com/api/v2/sql?q='

# define query function
def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urlencode({'format':format, 'q':query}).encode('utf-8')
    try:
        response = urlopen(source, data)
    except HTTPError as e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
# select stations within 800m of the Barclays Center
q1 = '''
SELECT
    start_station_id,
    CDB_TransformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude
        )
) as the_geom_webmercator, MIN(cartodb_id) as cartodb_id
FROM stations
WHERE
     ST_DWithin(CDB_LatLng(
         start_station_latitude,
         start_station_longitude
)::geography, CDB_LatLng(40.683048,-73.975961)::geography, %s)
GROUP BY
      start_station_id,
      start_station_latitude,
      start_station_longitude
'''%dist

nearby = pd.read_csv(io(queryCartoDB(q1)), sep=',')
nearby = list(nearby['start_station_id'])
nearby.sort()
print('# of stations within %s-meter range: %s'%(dist, len(nearby)))
# Out:
# # of stations within 800-meter range: 20

# %% [markdown]
# ## Subset and concatenate the major dataframe for analysis
# - Subset trips beginning from the nearby stations near the Barclays Center
# - Subset trips beginning between 16:00 - 24:00

# %%
# examine variables
print(CB.columns)
CB2 = pd.read_csv(os.getenv("PUIDATA") + "/" + '201601' + "-citibike-tripdata.csv")
print(CB2.columns)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# subset data by month and append as a list of 12 dfs
CB2016 = []
CBshape = []

for i in range(12):
    datestring = str(201601 + i)
    df = pd.read_csv(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv")
    #df.columns = [c.lower() for c in df.columns]
    df.columns = ['tripduration', 'starttime', 'stoptime',
                  'start station id', 'start station name', 'start station latitude', 'start station longitude',
                  'end station id', 'end station name', 'end station latitude', 'end station longitude',
                  'bikeid', 'usertype', 'birth year', 'gender']
    df = df[df['start station id'].apply(lambda x: x in nearby)]
    df['starttime'] = pd.to_datetime(df['starttime'])
    
    # subset trips after given hour in day to 24
    df = df[df['starttime'].dt.hour >= time]
    CB2016.append(df)
    CBshape.append(df.shape)

# %%
# concatenate data from all 12 months and validate merge
CB_concat = pd.concat(CB2016, axis=0)
CB_concat.reset_index(inplace=True)
CB_concat = CB_concat.drop('index', axis=1)

print('Total trips for 12 months: %s\nMerged shape: %s'%(sum([s[0] for s in CBshape]), CB_concat.shape))
CB_concat.head()
# Out:
# Total trips for 12 months: 60148
# Merged shape: (60148, 15)
#    tripduration           starttime           stoptime  start station id  \
# 0           173 2016-01-01 16:03:10  1/1/2016 16:06:03               243
# 1           136 2016-01-01 16:05:54  1/1/2016 16:08:11               420
# 2           653 2016-01-01 16:13:47  1/1/2016 16:24:40                83
# 3           659 2016-01-01 16:13:47  1/1/2016 16:24:46                83
# 4          1419 2016-01-01 16:20:39  1/1/2016 16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave
# 1               -73.969689             270      Adelphi St & Myrtle Ave
# 2               -73.976323             278       Concord St & Bridge St
# 3               -73.976323             278       Concord St & Bridge St
# 4               -73.976323             532              S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.689810             -73.974931   23976  Subscriber
# 1             40.693083             -73.971789   17362  Subscriber
# 2             40.697666             -73.984764   16270  Subscriber
# 3             40.697666             -73.984764   22909  Subscriber
# 4             40.710451             -73.960876   20506  Subscriber
#
#    birth year  gender
# 0      1971.0       2
# 1      1980.0       1
# 2      1976.0       1
# 3      1985.0       2
# 4      1993.0       1

# %%
# convert datetime format
CB_concat['stoptime'] = pd.to_datetime(CB_concat['stoptime'])

# split date and time to different columns
CB_concat['startdate'] = CB_concat['starttime'].dt.date
CB_concat['starttime'] = CB_concat['starttime'].dt.time
CB_concat['stopdate'] = CB_concat['stoptime'].dt.date
CB_concat['stoptime'] = CB_concat['stoptime'].dt.time
CB_concat.head()
# Out:
#    tripduration starttime  stoptime  start station id  \
# 0           173  16:03:10  16:06:03               243
# 1           136  16:05:54  16:08:11               420
# 2           653  16:13:47  16:24:40                83
# 3           659  16:13:47  16:24:46                83
# 4          1419  16:20:39  16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave
# 1               -73.969689             270      Adelphi St & Myrtle Ave
# 2               -73.976323             278       Concord St & Bridge St
# 3               -73.976323             278       Concord St & Bridge St
# 4               -73.976323             532              S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.689810             -73.974931   23976  Subscriber
# 1             40.693083             -73.971789   17362  Subscriber
# 2             40.697666             -73.984764   16270  Subscriber
# 3             40.697666             -73.984764   22909  Subscriber
# 4             40.710451             -73.960876   20506  Subscriber
#
#    birth year  gender   startdate    stopdate
# 0      1971.0       2  2016-01-01  2016-01-01
# 1      1980.0       1  2016-01-01  2016-01-01
# 2      1976.0       1  2016-01-01  2016-01-01
# 3      1985.0       2  2016-01-01  2016-01-01
# 4      1993.0       1  2016-01-01  2016-01-01

# %%
# export csv file
CB_concat.to_csv('CB2016_subset_%sm_%sh.csv'%(dist, time))
