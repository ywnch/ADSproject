# %% [markdown]
# # Data Analysis: OLS regressions WITHOUT weather variables
#
# ## This notebook:
# 1. Initiates several OLS regressions
# 2. Weather variables are later added in in ('Anls_OLS_weather.ipynb')

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('merged2_event_CB2016_800m.csv')
df.head()
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
# 1           1           136  16:05:54  16:08:11               420
# 2           2           653  16:13:47  16:24:40                83
# 3           3           659  16:13:47  16:24:46                83
# 4           4          1419  16:20:39  16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave
# 1               -73.969689             270      Adelphi St & Myrtle Ave
# 2               -73.976323             278       Concord St & Bridge St
# 3               -73.976323             278       Concord St & Bridge St
# 4               -73.976323             532              S 5 Pl & S 4 St
#
#    ...      usertype  birth year  gender   startdate    stopdate  Event_type  \
# 0  ...    Subscriber      1971.0       2  2016-01-01  2016-01-01    no-event
# 1  ...    Subscriber      1980.0       1  2016-01-01  2016-01-01    no-event
# 2  ...    Subscriber      1976.0       1  2016-01-01  2016-01-01    no-event
# 3  ...    Subscriber      1985.0       2  2016-01-01  2016-01-01    no-event
# 4  ...    Subscriber      1993.0       1  2016-01-01  2016-01-01    no-event
#
#   End_Time weekday      O_date O_hour
# 0      NaN     NaN  2016-01-01     16
# 1      NaN     NaN  2016-01-01     16
# 2      NaN     NaN  2016-01-01     16
# 3      NaN     NaN  2016-01-01     16
# 4      NaN     NaN  2016-01-01     16
#
# [5 rows x 23 columns]

# %%
df['startdate'] = pd.to_datetime(df['startdate'])
df['month'] = df['startdate'].dt.month
df['weekday'] = [i not in [5,6] for i in df['startdate'].dt.weekday.values]

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
# 1           1           136  16:05:54  16:08:11               420
# 2           2           653  16:13:47  16:24:40                83
# 3           3           659  16:13:47  16:24:46                83
# 4           4          1419  16:20:39  16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  ...   \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave  ...
# 1               -73.969689             270      Adelphi St & Myrtle Ave  ...
# 2               -73.976323             278       Concord St & Bridge St  ...
# 3               -73.976323             278       Concord St & Bridge St  ...
# 4               -73.976323             532              S 5 Pl & S 4 St  ...
#
#    birth year  gender  startdate    stopdate  Event_type  End_Time weekday  \
# 0      1971.0       2 2016-01-01  2016-01-01    no-event       NaN    True
# 1      1980.0       1 2016-01-01  2016-01-01    no-event       NaN    True
# 2      1976.0       1 2016-01-01  2016-01-01    no-event       NaN    True
# 3      1985.0       2 2016-01-01  2016-01-01    no-event       NaN    True
# 4      1993.0       1 2016-01-01  2016-01-01    no-event       NaN    True
#
#        O_date O_hour month
# 0  2016-01-01     16     1
# 1  2016-01-01     16     1
# 2  2016-01-01     16     1
# 3  2016-01-01     16     1
# 4  2016-01-01     16     1
#
# [5 rows x 24 columns]

# %%
df['Event_type'].unique()
# Out:
# array(['no-event', 'basketball', 'boxing', 'concert', 'other', 'hockey',
#        'family'], dtype=object)

# %%
# df['Event_type'][df['Event_type'].isnull()] = 'none'

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
# 1           1           136  16:05:54  16:08:11               420
# 2           2           653  16:13:47  16:24:40                83
# 3           3           659  16:13:47  16:24:46                83
# 4           4          1419  16:20:39  16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  ...   \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave  ...
# 1               -73.969689             270      Adelphi St & Myrtle Ave  ...
# 2               -73.976323             278       Concord St & Bridge St  ...
# 3               -73.976323             278       Concord St & Bridge St  ...
# 4               -73.976323             532              S 5 Pl & S 4 St  ...
#
#    birth year  gender  startdate    stopdate  Event_type  End_Time weekday  \
# 0      1971.0       2 2016-01-01  2016-01-01    no-event       NaN    True
# 1      1980.0       1 2016-01-01  2016-01-01    no-event       NaN    True
# 2      1976.0       1 2016-01-01  2016-01-01    no-event       NaN    True
# 3      1985.0       2 2016-01-01  2016-01-01    no-event       NaN    True
# 4      1993.0       1 2016-01-01  2016-01-01    no-event       NaN    True
#
#        O_date O_hour month
# 0  2016-01-01     16     1
# 1  2016-01-01     16     1
# 2  2016-01-01     16     1
# 3  2016-01-01     16     1
# 4  2016-01-01     16     1
#
# [5 rows x 24 columns]

# %%
# define season
df['season'] = df['month'].map({1: 1,
                               2: 1,
                               3: 2,
                               4: 2,
                               5: 2,
                               6: 3,
                               7: 3,
                               8: 3,
                               9: 4,
                               10: 4,
                               11: 4,
                               12: 1})
df.head()
# Out:
#    Unnamed: 0  tripduration starttime  stoptime  start station id  \
# 0           0           173  16:03:10  16:06:03               243
# 1           1           136  16:05:54  16:08:11               420
# 2           2           653  16:13:47  16:24:40                83
# 3           3           659  16:13:47  16:24:46                83
# 4           4          1419  16:20:39  16:44:19                83
#
#               start station name  start station latitude  \
# 0        Fulton St & Rockwell Pl               40.688226
# 1   Clermont Ave & Lafayette Ave               40.687645
# 2  Atlantic Ave & Fort Greene Pl               40.683826
# 3  Atlantic Ave & Fort Greene Pl               40.683826
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id             end station name  \
# 0               -73.979382             241  DeKalb Ave & S Portland Ave
# 1               -73.969689             270      Adelphi St & Myrtle Ave
# 2               -73.976323             278       Concord St & Bridge St
# 3               -73.976323             278       Concord St & Bridge St
# 4               -73.976323             532              S 5 Pl & S 4 St
#
#    ...    gender  startdate    stopdate Event_type  End_Time  weekday  \
# 0  ...         2 2016-01-01  2016-01-01   no-event       NaN     True
# 1  ...         1 2016-01-01  2016-01-01   no-event       NaN     True
# 2  ...         1 2016-01-01  2016-01-01   no-event       NaN     True
# 3  ...         2 2016-01-01  2016-01-01   no-event       NaN     True
# 4  ...         1 2016-01-01  2016-01-01   no-event       NaN     True
#
#        O_date O_hour month season
# 0  2016-01-01     16     1      1
# 1  2016-01-01     16     1      1
# 2  2016-01-01     16     1      1
# 3  2016-01-01     16     1      1
# 4  2016-01-01     16     1      1
#
# [5 rows x 25 columns]

# %%
d = pd.DataFrame(df.groupby(['O_date','Event_type','O_hour','weekday','season'],as_index=False).size())
d.reset_index(inplace=True)
d.columns = ['O_date','Event_type','O_hour','weekday','season','Count']
d.head()
# Out:
#        O_date Event_type  O_hour  weekday  season  Count
# 0  2016-01-01   no-event      16     True       1      8
# 1  2016-01-01   no-event      17     True       1      7
# 2  2016-01-01   no-event      18     True       1      4
# 3  2016-01-01   no-event      19     True       1      2
# 4  2016-01-01   no-event      20     True       1      2

# %%
lm0 = smf.ols(formula="Count ~ weekday + O_hour + C(Event_type, Treatment(reference='no-event'))",data=d).fit()
lm0.summary()

f = open('lm0.txt', 'w')
f.write(lm0.summary().as_text())
f.close()

# %%
lm1 = smf.ols(formula="Count ~ weekday + O_hour * C(Event_type, Treatment(reference='no-event'))",data=d).fit()
lm1.summary()

f = open('lm1.txt', 'w')
f.write(lm1.summary().as_text())
f.close()

# %%
lm2 = smf.ols(formula="Count ~ season + weekday + O_hour * C(Event_type, Treatment(reference='no-event'))",data=d).fit()
lm2.summary()

f = open('lm2.txt', 'w')
f.write(lm2.summary().as_text())
f.close()

# %%
lm3 = smf.ols(formula="Count ~ weekday + season * O_hour * C(Event_type, Treatment(reference='no-event'))",data=d).fit()
lm3.summary()

f = open('lm3.txt', 'w')
f.write(lm3.summary().as_text())
f.close()

# %% [markdown]
# ## Run regression on Aug-Dec only

# %%
d2 = d[pd.to_datetime(d['O_date']).dt.month > 7]

# %%
lm4 = smf.ols(formula="Count ~ weekday + season * O_hour * C(Event_type, Treatment(reference='no-event'))",data=d2).fit()
lm4.summary()

f = open('lm4.txt', 'w')
f.write(lm4.summary().as_text())
f.close()
